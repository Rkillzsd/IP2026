# %% [markdown]
# ## List Comprehensions

# %%
li = [3, 6, 2, 7]
out = []
print(out)
for elem in li:
    out.append(elem*2)
    print(out)
# Out:
# []
# [6]
# [6, 12]
# [6, 12, 4]
# [6, 12, 4, 14]

# %%
[elem*2 for elem in li]
## 반복할거 for 리스트 형태 in 리스트(원소수 만큼)
# Out:
# [6, 12, 4, 14]

# %%
li = [('a', 1), ('b', 2), ('c' , 7)]
[ n * 3 for (x, n) in li]
# Out:
# [3, 6, 21]
