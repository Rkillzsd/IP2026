# %% [markdown]
# ## Geometric Transformations of Images

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

img = cv2.imread('opencv_logo.png',0)
rows, cols = img.shape
res1 = cv2.resize(img,None,fx=2, fy=2, interpolation = cv2.INTER_LINEAR)
res2 = cv2.resize(img,None,fx=2, fy=2, interpolation = cv2.INTER_AREA)
res3 = cv2.resize(img,None,fx=2, fy=2, interpolation = cv2.INTER_CUBIC)

# %%
cv2.namedWindow('res1')
cv2.namedWindow('res2')
cv2.namedWindow('res3')
cv2.resizeWindow('res1',cols*2,rows*2)
cv2.resizeWindow('res2',cols*2,rows*2)
cv2.resizeWindow('res3',cols*2,rows*2)
while(1):
    cv2.imshow('res1',res1)
    cv2.imshow('res2',res2)
    cv2.imshow('res3',res3)
    k=cv2.waitKey(1)&0xFF
    if k== 27:
        break
cv2.destroyAllWindows()

# %% [markdown]
# ## Translation

# %%
rows,cols = img.shape
M = np.float32([[1,0,100],[0,1,50]])
dst = cv2.warpAffine(img,M,(cols,rows))
cv2.imshow('img',img)
cv2.imshow('dst',dst)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ## Rotation

# %%
M = cv2.getRotationMatrix2D((cols/2,rows/2),45,1)
dst = cv2.warpAffine(img,M,(cols,rows))
cv2.imshow('img',img)
cv2.imshow('dst',dst)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ## Affine Transformation

# %%
img = cv2.imread('gradient.jpg')
rows,cols,ch = img.shape
pts1 = np.float32([[50,50],[200,50],[50,200]])
pts2 = np.float32([[10,100],[200,50],[100,250]])
M = cv2.getAffineTransform(pts1,pts2)
dst = cv2.warpAffine(img,M,(cols,rows))
plt.subplot(121),plt.imshow(img),plt.title('Input')
plt.subplot(122),plt.imshow(dst),plt.title('Output')
plt.show()

# %% [markdown]
# ## Perspective Transformation

# %%
img = cv2.imread('dsu1.jpg',)
rows,cols,ch = img.shape
pts1 = np.float32([[323,282],[760, 310],[765,509],[322,534]])
pts2 = np.float32([[300,300],[800,300],[800,600],[300,600]])
M = cv2.getPerspectiveTransform(pts1,pts2)
dst = cv2.warpPerspective(img,M,(1100,900))
plt.subplot(121),plt.imshow(img),plt.title('Input')
plt.subplot(122),plt.imshow(dst),plt.title('Output')
plt.show()

# %%
img = cv2.imread('dsu3.jpg',)
rows,cols,ch = img.shape
pts1 = np.float32([[100,225],[702, 160],[702,538],[113,500]])
pts2 = np.float32([[100,100],[900,100],[900,700],[100,700]])
M = cv2.getPerspectiveTransform(pts1,pts2)
dst = cv2.warpPerspective(img,M,(1000,800))
plt.subplot(121),plt.imshow(img),plt.title('Input')
plt.subplot(122),plt.imshow(dst),plt.title('Output')
plt.show()

# %%
img = cv2.imread('IMG_6504.jpg',)
rows,cols,ch = img.shape
pts1 = np.float32([[167,188],[758, 194],[800,1090],[98,1084]])
pts2 = np.float32([[50,50],[850,50],[850,1150],[50,1150]])
M = cv2.getPerspectiveTransform(pts1,pts2)
dst = cv2.warpPerspective(img,M,(900,1200))
plt.subplot(121),plt.imshow(img),plt.title('Input')
plt.subplot(122),plt.imshow(dst),plt.title('Output')
plt.show()
